# %%
from emerald_monitor import ResourceMonitor

# %%
import numpy as np
import time

# %%
def random_fn():
    time.sleep(0.25)
    print(f"time.sleep(0.25)")
    
    a = np.random.randint(0,1000, (1, 1000))
    print(f"a = np.random.randint(0,1000, (1, 1000))")
    print(f"np.shape(a) = {np.shape(a)}")
    
    b = np.tile(a, (1000, 1))
    print("b = np.tile(a, (1000, 1))")
    print(f"np.shape(b) = {np.shape(b)}")
    
    c = a*b
    print('c = a*b')
    print(f"np.shape(c) = {np.shape(c)}")
    
    d = np.random.randint(0, 1000, (np.shape(c)))
    print('d = np.random.randint(0, 1000, (np.shape(c)))')
    print(f"np.shape(d) = {np.shape(d)}")
    
    e = c*d
    print('e = c*d')
    print(f"np.shape(e) = {np.shape(e)}")
    
    time.sleep(0.25)
    print(f"time.sleep(0.25)")

# %%
logging_interval=0.00001
print(f"logging_interval = {logging_interval} times per second")
# Out:
# logging_interval = 1e-05 times per second

# %%
moni = ResourceMonitor(logging_interval=logging_interval)
moni.start_logging()

random_fn()

moni.stop_logging()
# Out:
# time.sleep(0.25)
# a = np.random.randint(0,1000, (1, 1000))
# np.shape(a) = (1, 1000)
# b = np.tile(a, (1000, 1))
# np.shape(b) = (1000, 1000)
# c = a*b
# np.shape(c) = (1000, 1000)
# d = np.random.randint(0, 1000, (np.shape(c)))
# np.shape(d) = (1000, 1000)
# e = c*d
# np.shape(e) = (1000, 1000)
# time.sleep(0.25)

# %%
moni.plot_logs()

# %%
print(moni.get_logs())
# Out:
#          epoch_time  elapsed_time  memory_rss  cpu_times_user  \
# 0      1.720093e+09      0.000000    0.119934        0.996132
# 1      1.720093e+09      0.000156    0.119934        0.996255
# 2      1.720093e+09      0.000229    0.119934        0.996305
# 3      1.720093e+09      0.000273    0.119934        0.996333
# 4      1.720093e+09      0.000359    0.119934        0.996399
# ...             ...           ...         ...             ...
# 26657  1.720093e+09      0.516857    0.158890        1.110559
# 26658  1.720093e+09      0.516875    0.158890        1.110563
# 26659  1.720093e+09      0.516893    0.158890        1.110567
# 26660  1.720093e+09      0.516912    0.158890        1.110571
# 26661  1.720093e+09      0.516971    0.158890        1.110619
#
#        cpu_times_system  cpu_times_total  gm_year  gm_month  gm_day  \
# 0              2.072962         3.069094   2024.0       7.0     4.0
# 1              2.072994         3.069249   2024.0       7.0     4.0
# 2              2.073013         3.069317   2024.0       7.0     4.0
# 3              2.073054         3.069387   2024.0       7.0     4.0
# 4              2.073171         3.069571   2024.0       7.0     4.0
# ...                 ...              ...      ...       ...     ...
# 26657          2.126813         3.237372   2024.0       7.0     4.0
# 26658          2.126815         3.237378   2024.0       7.0     4.0
# 26659          2.126816         3.237383   2024.0       7.0     4.0
# 26660          2.126818         3.237389   2024.0       7.0     4.0
# 26661          2.126833         3.237452   2024.0       7.0     4.0
#
#             gm_time
# 0      11:32:47.134
# 1      11:32:47.135
# 2      11:32:47.135
# 3      11:32:47.135
# 4      11:32:47.135
# ...             ...
# 26657  11:32:47.651
# 26658  11:32:47.651
# 26659  11:32:47.651
# 26660  11:32:47.651
# 26661  11:32:47.651
#
# [26662 rows x 10 columns]
